# %% [markdown]
# ## Data download from "https://data.boston.gov/dataset/employee-earnings-report"
#
# ## From year 2011 to 2021

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go


# file=pd.read_csv('preYear.csv')
# set(file)
file22=pd.read_csv('./Data/employees-2022.csv',thousands=',', encoding='latin-1')
file21=pd.read_csv('./Data/employees-2021.csv',thousands=',', encoding='latin-1')
file20=pd.read_csv('./Data/employees-2020.csv',thousands=',', encoding='latin-1')
file19=pd.read_csv('./Data/employees-2019.csv',thousands=',', encoding='latin-1')
file18=pd.read_csv('./Data/employees-2018.csv',thousands=',', encoding='latin-1')
file17=pd.read_csv('./Data/employees-2017.csv',thousands=',', encoding='latin-1')
file16=pd.read_csv('./Data/employees-2016.csv',thousands=',', encoding='latin-1')
file15=pd.read_csv('./Data/employees-2015.csv',thousands=',', encoding='latin-1')
file14=pd.read_csv('./Data/employees-2014.csv',thousands=',', encoding='latin-1')
file13=pd.read_csv('./Data/employees-2013.csv',thousands=',', encoding='latin-1')
file12=pd.read_csv('./Data/employees-2012.csv',thousands=',', encoding='latin-1')
file11=pd.read_csv('./Data/employees-2011.csv',thousands=',', encoding='latin-1')

file22['NAME'] = file22['NAME'].apply(lambda x: str(x).replace(",",", "))
file21['NAME'] = file21['NAME'].apply(lambda x: str(x).replace(",",", "))
file20['NAME'] = file20['NAME'].apply(lambda x: str(x).replace(",",", "))
file19['NAME'] = file19['NAME'].apply(lambda x: str(x).replace(",",", "))
file18['NAME'] = file18['NAME'].apply(lambda x: str(x).replace(",",", "))
file17['NAME'] = file17['NAME'].apply(lambda x: str(x).replace(",",", "))
file16['NAME'] = file16['NAME'].apply(lambda x: str(x).replace(",",", "))
file15['NAME'] = file15['NAME'].apply(lambda x: str(x).replace(",",", "))
file14['NAME'] = file14['NAME'].apply(lambda x: str(x).replace(",",", "))
file13['NAME'] = file13['NAME'].apply(lambda x: str(x).replace(",",", "))
file12['NAME'] = file12['NAME'].apply(lambda x: str(x).replace(",",", "))
file11['Name'] = file11['Name'].apply(lambda x: str(x).replace(",",", "))

df22 = pd.DataFrame(file22)
df21 = pd.DataFrame(file21)
df20 = pd.DataFrame(file20)
df19 = pd.DataFrame(file19)
df18 = pd.DataFrame(file18)
df17 = pd.DataFrame(file17)
df16 = pd.DataFrame(file16)
df15 = pd.DataFrame(file15)
df14 = pd.DataFrame(file14)
df13 = pd.DataFrame(file13)
df12 = pd.DataFrame(file12)
df11 = pd.DataFrame(file11)

df22= df22.loc[df22['DEPARTMENT_NAME'] == 'Boston Police Department']
df21= df21.loc[df21['DEPARTMENT_NAME'] == 'Boston Police Department']
df20= df20.loc[df20['DEPARTMENT_NAME'] == 'Boston Police Department']
df19= df19.loc[df19['DEPARTMENT_NAME'] == 'Boston Police Department']
df18= df18.loc[df18['DEPARTMENT_NAME'] == 'Boston Police Department']
df17= df17.loc[df17['DEPARTMENT NAME'] == 'Boston Police Department']
df16= df16.loc[df16['DEPARTMENT_NAME'] == 'Boston Police Department']
df15= df15.loc[df15['DEPARTMENT_NAME'] == 'Boston Police Department']
df14= df14.loc[df14['DEPARTMENT NAME'] == 'Boston Police Department']
df13= df13.loc[df13['DEPARTMENT'] == 'Boston Police Department']
df12= df12.loc[df12['DEPARTMENT'] == 'Boston Police Department']
df11= df11.loc[df11['Department Name'] == 'Boston Police Department']

print(df22.shape)
print(df21.shape)
print(df20.shape)
print(df19.shape)
print(df18.shape)
print(df17.shape)
print(df16.shape)
print(df15.shape)
print(df14.shape)
print(df13.shape)
print(df12.shape)
print(df11.shape)
# Out:
# (3040, 12)
# (3094, 12)
# (3142, 12)
# (3271, 12)
# (3173, 12)
# (3149, 12)
# (3114, 12)
# (3034, 12)
# (3178, 12)
# (3085, 12)
# (3034, 12)
# (3013, 12)

# %%
top_gross_22=df22.sort_values(by='TOTAL_ GROSS',ascending=False)
top20_gross_22=top_gross_22.head(20)

fig = px.bar(top20_gross_22, x='TOTAL_ GROSS', y='NAME', orientation='h', title='<b>2022 Top Earners<b>', color_discrete_sequence=['#130F54'])
# remove the x and y labels
fig.update_layout(xaxis_title='', yaxis_title='')
fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# make the background color to be transparent 
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')
fig.update_yaxes(autorange="reversed")
# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050,
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in 2022",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)

fig.show()

# %%
top20_gross_22['RETRO'] = top20_gross_22['RETRO'].fillna(0)
top20_gross_22['OVERTIME'] = top20_gross_22['OVERTIME'].fillna(0)
top20_gross_22['INJURED'] = top20_gross_22['INJURED'].fillna(0)
top20_gross_22['DETAIL'] = top20_gross_22['DETAIL'].fillna(0)

# Create new col
top20_gross_22['ALL_OTHER'] = top20_gross_22['RETRO'] + top20_gross_22['OTHER'] + top20_gross_22['INJURED'] + top20_gross_22['DETAIL'] + top20_gross_22['QUINN_EDUCATION']

top20_gross_22.head(20)
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_92419/1344111313.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_92419/1344111313.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_92419/1344111313.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
top20_gross_22 = top20_gross_22.rename(columns={"REGULAR": "Regular", "OVERTIME": "Overtime", "ALL_OTHER": "All Other"})

fig = px.bar(top20_gross_22, x=['Regular', 'Overtime', 'All Other'], y='NAME', orientation='h', title='<b>2022 Top Earners<b>', color_discrete_sequence=['#130F54', '#EF404E', '#BBBBBB'])
# remove the x and y labels
fig.update_layout(xaxis_title='', yaxis_title='')
fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# make the background color to be transparent 
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')
fig.update_yaxes(autorange="reversed")
# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050,
    legend_title_text='Pay Types'
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="Type of Earnings from BPD's Top Earners in 2022",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.update_traces(marker_line_width = 0)


fig.show()

# %%
top21=df21.sort_values(by='TOTAL_GROSS',ascending=False)

top21_20=top21.head(20)
label2021=list(top21_20['NAME'])
value=list(top21_20['TOTAL_GROSS'])
plt.rcdefaults()
fig, ax = plt.subplots()
people=label2021
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)
ax.set_xlabel('unit=100')
ax.set_title('2021 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_92419/4112242737.py:21: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
color_list=['#0055aa']

# %%
# do the same thing as above but useing plotly
#  randomly use the color in the color list to color the bars, but #0055aa or #EF404E must be used at least once
# remove the x and y labels
# top21=df21.sort_values(by='TOTAL_GROSS',ascending=False)

fig = px.bar(top21_20, x='TOTAL_GROSS', y='NAME', orientation='h', title='<b>2021 Top Earners<b>', color_discrete_sequence=['#130F54'])
# remove the x and y labels
fig.update_layout(xaxis_title='', yaxis_title='')
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))


# make the background color to be transparent 
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')
fig.update_yaxes(autorange="reversed")
# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050,
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2021",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)



fig.show()

# %%
print(people)
# Out:
# ['Beckers, Richard', 'McGowan, Jacqueline M.', 'Harris, Shawn N', 'Washington, Walter', 'Mosley Jr., Curtis', 'Joseph, Martin M', 'Demesmin, Stanley', 'Smith, Sean P', 'Lee, Waiman', 'Barrett, Thomas E.', 'Danilecki, John H', 'Webb, Keith A', 'Sweeney, Steven', 'Brown, John M', 'Kervin, Timothy M.', 'Downing, George C', 'Connolly, Timothy', 'Harrington, Mark William', 'Gero, Jarrod A', 'Pusey, Daniel C.']

# %%
df20[' TOTAL EARNINGS '] = df20[' TOTAL EARNINGS '].replace({'\$':''}, regex = True)

for i in range(len(df20[' TOTAL EARNINGS '])):
    df20[' TOTAL EARNINGS '][i]=df20[' TOTAL EARNINGS '][i][1:-1].replace(',','')
    
df20[' TOTAL EARNINGS '] = df20[' TOTAL EARNINGS '].astype(float)
    


top20=df20.sort_values(by=' TOTAL EARNINGS ',ascending=False)

top20_20=top20.head(20)


label2020=list(top20_20['NAME'])
value=list(top20_20[' TOTAL EARNINGS '])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2020
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2020 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 8
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# the above thing but useing plotly

fig = px.bar(top20_20, x=' TOTAL EARNINGS ', y='NAME', color='NAME', orientation='h', title='<b>2020 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

# make the background color to be transparent 
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2020",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)


fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 3
#       1 # the above thing but useing plotly
# ----> 3 fig = px.bar(top20_20, x=' TOTAL EARNINGS ', y='NAME', color='NAME', orientation='h', title='<b>2020 Top Earners<b>', color_discrete_sequence=['#130F54'])
#       4 fig.update_layout(showlegend=False)
#       5 fig.update_layout(font_family="GT America Bold")
#
# NameError: name 'top20_20' is not defined

# %%
df19['TOTAL EARNINGS'] = df19['TOTAL EARNINGS'].astype(float)

top19=df19.sort_values(by='TOTAL EARNINGS',ascending=False)

top19_20=top19.head(20)


label2019=list(top19_20['NAME'])
value=list(top19_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2019
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2019 Top Earners ')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1735128800.py:26: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
# do the above thing but useing plotly

# show all the names on left side remove the name on right side

fig = px.bar(top19_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2019 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(showlegend=False)
fig.update_layout(xaxis_title='', yaxis_title='')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# increase the hight of the plot
fig.update_layout(height=600)

# make the background color to be transparent 
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2019",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
#remove the , from Total Earnings
df18['TOTAL EARNINGS'] = df18['TOTAL EARNINGS'].replace({'\$':''}, regex = True)
# Convert total earning to float
for i in range(len(df18['TOTAL EARNINGS'])):
    df18['TOTAL EARNINGS'][i]=df18['TOTAL EARNINGS'][i][1:-1].replace(',','')




for i in range(len(df18['TOTAL EARNINGS'])):
    if df18['TOTAL EARNINGS'][i]=='OTAL EARNING':
        df18['TOTAL EARNINGS'][i]='0'


    
df18['TOTAL EARNINGS'] = df18['TOTAL EARNINGS'].astype(float)
    


top18=df18.sort_values(by='TOTAL EARNINGS',ascending=False)

top18_20=top18.head(20)


label2018=list(top18_20['NAME'])
value=list(top18_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2018
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2018 Top Earners')
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/1236189685.py:43: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
# did the above thing but useing plotly

fig = px.bar(top18_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2018 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# make the background color to be transparent 
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2018",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
df17['TOTAL EARNINGS'] = df17['TOTAL EARNINGS'].replace({'\$':''}, regex = True)




top17=df17.sort_values(by='TOTAL EARNINGS',ascending=False)

top17_20=top17.head(20)


label2017=list(top17_20['NAME'])
value=list(top17_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2017
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2017 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

#change the bar in a descending order
ax.invert_yaxis()

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/2584317335.py:30: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
# did the above thing but useing plotly

# did the same thing as top18_20 in plotly


fig = px.bar(top17_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2017 Top Earners<b>', color_discrete_sequence=['#130F54'])




fig.update_layout(xaxis_title='', yaxis_title='')

#change the bar in a descending order
fig.update_layout(showlegend=False)
fig.update_layout(yaxis={'categoryorder':'total ascending'})

# make the background color to be transparent 
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2017",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)

fig.show()

# %%
print(people)
# Out:
# ['Kersey, Pamela S.', 'Doyle, Christine M', 'Patel, Aakash Vasant', 'Adduci, Vincent R.', 'Muller, Robert F.', 'Coffey, Katherine A', 'Costa, Maureen R', 'Smith, Johanna B', 'Saba, Marilyn R', 'Platukis, Janet C', 'Corvera De Pineda, Angela', 'Viall, Gemanique', 'Minniti, Patricia A.', 'Bourgoin, Marli Salomao', 'Cesario, Daniel M', 'Liming, Todd', 'Moller, Marsha B.', 'Reines-Leo, Alicia Joy', 'Dickie, Michelle T', 'Joyal, Stephen']

# %%
df16['TOTAL EARNINGS'] = df16['TOTAL EARNINGS'].replace({'\$':''}, regex = True)




for i in range(len(df16['TOTAL EARNINGS'])):
    df16['TOTAL EARNINGS'][i]=df16['TOTAL EARNINGS'][i].replace(' ','').replace(',','')




df16['TOTAL EARNINGS'] = df16['TOTAL EARNINGS'].astype(float)



top16=df16.sort_values(by='TOTAL EARNINGS',ascending=False)

top16_20=top16.head(20)


label2016=list(top16_20['NAME'])
value=list(top16_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2016
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2016 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/1041130764.py:40: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
fig = px.bar(top16_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2016 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular


# increase the hight of the plot
fig.update_layout(height=600)

# make the background color to be transparent 
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')
fig.update_layout(showlegend=False)

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2016",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)

fig.show()

# %%
df15['TOTAL EARNINGS'] = df15['TOTAL EARNINGS'].replace({'\$':''}, regex = True)



df15 = pd.DataFrame(file15)
for i in range(len(df15['TOTAL EARNINGS'])):
    df15['TOTAL EARNINGS'][i]=df15['TOTAL EARNINGS'][i].replace(' ','').replace(',','')




df15['TOTAL EARNINGS'] = df15['TOTAL EARNINGS'].astype(float)



top15=df15.sort_values(by='TOTAL EARNINGS',ascending=False)

top15_20=top15.head(20)


label2015=list(top15_20['NAME'])
value=list(top15_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2015
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2015 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/3740423900.py:40: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
fig = px.bar(top15_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2015 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2015",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
# df14=pd.DataFrame(file14)
df14['TOTAL EARNINGS'] = df14['TOTAL EARNINGS'].replace({'\$':''}, regex = True)

# df14 = pd.DataFrame(file14)
for i in range(len(df14['TOTAL EARNINGS'])):
    df14['TOTAL EARNINGS'][i]=df14['TOTAL EARNINGS'][i].replace(' ','').replace(',','')

df14['TOTAL EARNINGS'] = df14['TOTAL EARNINGS'].astype(float)

top14=df14.sort_values(by='TOTAL EARNINGS',ascending=False)

top14_20=top14.head(20)

label2014=list(top14_20['NAME'])
value=list(top14_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2014
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2014 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
fig = px.bar(top14_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2014 Top Earners<b>', color_discrete_sequence=['#130F54'])
# bold the title

fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2014",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
# df13['TOTAL EARNINGS'] = df13['TOTAL EARNINGS'].replace({'\$':''}, regex = True)

df13 = pd.DataFrame(file13)
for i in range(len(df13['TOTAL EARNINGS'])):
    df13['TOTAL EARNINGS'][i]=df13['TOTAL EARNINGS'][i].replace(' ','').replace(',','')

df13['TOTAL EARNINGS'] = df13['TOTAL EARNINGS'].astype(float)

top13=df13.sort_values(by='TOTAL EARNINGS',ascending=False)

top13_20=top13.head(20)

label2013=list(top13_20['NAME'])
value=list(top13_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2013
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2013 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [45], line 7
#       4 for i in range(len(df13['TOTAL EARNINGS'])):
#       5     df13['TOTAL EARNINGS'][i]=df13['TOTAL EARNINGS'][i].replace(' ','').replace(',','')
# ----> 7 df13['TOTAL EARNINGS'] = df13['TOTAL EARNINGS'].astype(float)
#       9 top13=df13.sort_values(by='TOTAL EARNINGS',ascending=False)
#      11 top13_20=top13.head(20)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
#    6239         self.iloc[:, i].astype(dtype, copy=copy)
#    6240         for i in range(len(self.columns))
#    6241     ]
#    6243 else:
#    6244     # else, only a single dtype is given
# -> 6245     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
fig = px.bar(top13_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2013 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2013",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [46], line 1
# ----> 1 fig = px.bar(top13_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2013 Top Earners<b>', color_discrete_sequence=['#130F54'])
#       2 fig.update_layout(xaxis_title='', yaxis_title='')
#       3 # remove the namme roll on the right side of the plot
#
# NameError: name 'top13_20' is not defined

# %%
df12=pd.DataFrame(file12)
df12['TOTAL EARNINGS'] = df12['TOTAL EARNINGS'].replace({'\$':''}, regex = True)

for i in range(len(df12['TOTAL EARNINGS'])):
    df12['TOTAL EARNINGS'][i]=df12['TOTAL EARNINGS'][i].replace(' ','').replace(',','')

df12['TOTAL EARNINGS'] = df12['TOTAL EARNINGS'].astype(float)

top12=df12.sort_values(by='TOTAL EARNINGS',ascending=False)

top12_20=top12.head(20)

label2012=list(top12_20['NAME'])
value=list(top12_20['TOTAL EARNINGS'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2012
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

ax.set_title('2012 Top Earners')

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/1136452575.py:29: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
fig = px.bar(top12_20, x='TOTAL EARNINGS', y='NAME', color='NAME', orientation='h', title='<b>2012 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2012",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
df11=pd.DataFrame(file11)

df11['Total Earnings'] = df11['Total Earnings'].replace({'\$':''}, regex = True)

for i in range(len(df11['Total Earnings'])):
    df11['Total Earnings'][i]=df11['Total Earnings'][i].replace(' ','').replace(',','')

df11['Total Earnings'] = df11['Total Earnings'].astype(float)

top11=df11.sort_values(by='Total Earnings',ascending=False)

top11_20=top11.head(20)


label2011=list(top11_20['Name'])
value=list(top11_20['Total Earnings'])

plt.rcdefaults()
fig, ax = plt.subplots()
people=label2011
y_pos = np.arange(len(people))
performance=value
ax.barh(y_pos, performance)
ax.set_yticks(y_pos)
ax.set_yticklabels(people)
ax.invert_yaxis()# labels read top-to-bottom
ax.set_yticklabels(people, fontsize=10)

ax.set_title('2011 Top Earners')
#Change the color or bars to red and black
ax.barh(y_pos, performance, color=['red', 'black'])
# Add the gridlines
ax.grid(b=True, color='grey', linestyle='-.', linewidth=0.5, alpha=0.2)

plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_15096/3899141013.py:33: MatplotlibDeprecationWarning:
#
# The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.

# %%
fig = px.bar(top11_20, x='Total Earnings', y='Name', color='Name', orientation='h', title='<b>2011 Top Earners<b>', color_discrete_sequence=['#130F54'])
fig.update_layout(xaxis_title='', yaxis_title='')
# remove the namme roll on the right side of the plot
fig.update_layout(showlegend=False)

# use Use GT America font
fig.update_layout(font_family="GT America Bold")
# change the front of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America", size=12, color="#000000"))

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    font_size=14,
    xaxis_title=None,
    yaxis_title=None,
    xaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=800,
    width=1050
)

# Customize title!
fig.update_layout(
    title=go.layout.Title(
        text="BPD's Top Earners by Total Gross Income in FY 2011",
        xref="paper",
        x=0,
        y=.95,
        font_family="GT America Bold",
        font_size=24
    )
)
fig.show()

# %%
def duplicate_removal(A, B):
    return set(A).intersection(set(B))

# %%
a=list(duplicate_removal(label2021,label2020))
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 a=list(duplicate_removal(label2021,label2020))
#       2 a
#
# NameError: name 'label2020' is not defined

# %%
b=list(duplicate_removal(a,label2019))
b
# Out:
# ['Kervin, Timothy M.',
#  'Hocking, Michael E',
#  'Sweeney, Steven',
#  'Danilecki, John H',
#  'Webb, Keith A',
#  'Lee, Waiman',
#  'Smith, Sean P',
#  'Barrett, Thomas E.',
#  'Brown, John M']

# %%
c=list(duplicate_removal(b,label2018))
c
# Out:
# []

# %%
d=duplicate_removal(label2016,label2017)
d
# Out:
# set()

# %%
e=duplicate_removal(label2016,label2015)
e
# Out:
# {'Danilecki, John H', 'Hosein, Haseeb', 'Kervin, Timothy M.', 'Lee, Waiman'}

# %%
f=duplicate_removal(e,label2014)
f
# Out:
# {'Danilecki, John H', 'Hosein, Haseeb', 'Kervin, Timothy M.'}

# %%
g=duplicate_removal(f,label2013)

# %%
g
# Out:
# {'Danilecki, John H', 'Hosein, Haseeb', 'Kervin, Timothy M.'}

# %%
h=duplicate_removal(g,label2012)
h
# Out:
# {'Danilecki, John H', 'Hosein, Haseeb', 'Kervin, Timothy M.'}

# %%
i=duplicate_removal(h,label2011)

# %%
i
# Out:
# {'Danilecki, John H', 'Hosein, Haseeb', 'Kervin, Timothy M.'}

# %%
ot21= df21['OVERTIME'].dropna()
ot21=ot21.astype(float)

ot20=df20[' OVERTIME '].replace({'\$':''}, regex = True).dropna()

#ot20=ot20.str.replace(' ','')

#ot20=ot20.str.replace(',','')
ot20=ot20.str.replace('[^0-9.]','')
ot20=ot20.astype(float)

# did the aboce form df19-11
ot19=df19[' OVERTIME '].replace({'\$':''}, regex = True).dropna()
ot19=ot19.str.replace('[^0-9.]','')

ot19=ot19[ot19.str.len()>0].astype(float)

ot18=df18['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot18=ot18.str.replace('[^0-9.]','')
ot18=ot18[ot18.str.len()>0].astype(float)

ot17=df17['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot17=ot17.str.replace('[^0-9.]','')
ot17=ot17[ot17.str.len()>0].astype(float)

ot16=df16['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot16=ot16.str.replace('[^0-9.]','')
ot16=ot16[ot16.str.len()>0].astype(float)

ot15=df15['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot15=ot15.str.replace('[^0-9.]','')
ot15=ot15[ot15.str.len()>0].astype(float)

ot14=df14['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot14=ot14.str.replace('[^0-9.]','')
ot14=ot14[ot14.str.len()>0].astype(float)

ot13=df13['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot13=ot13.str.replace('[^0-9.]','')
ot13=ot13[ot13.str.len()>0].astype(float)

ot12=df12['OVERTIME'].replace({'\$':''}, regex = True).dropna()
ot12=ot12.str.replace('[^0-9.]','')
ot12=ot12[ot12.str.len()>0].astype(float)

ot11=df11['Overtime'].replace({'\$':''}, regex = True).dropna()
ot11=ot11.str.replace('[^0-9.]','')
ot11=ot11[ot11.str.len()>0].astype(float)
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1321037731.py:9: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1321037731.py:14: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1321037731.py:19: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1321037731.py:23: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_66821/1321037731.py:27: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# ...

# %%
import pandas as pd

# count the total Over time of the each year
ot2021=df21['OVERTIME'].sum()
ot2020=ot20.sum()
ot2019=ot19.sum()
ot2018=ot18.sum()
ot2017=ot17.sum()
ot2016=ot16.sum()
ot2015=ot15.sum()
ot2014=ot14.sum()
ot2013=ot13.sum()
ot2012=ot12.sum()
ot2011=ot11.sum()



# count the number of OVER TIME colnums of the each year is the length of row is not zero or not null 
numot2021=len(df21['OVERTIME'].dropna())

# graph the above data x is the number of OVER TIME colnums and y is the total Over time of the each year by seaborn library
import seaborn as sns

x=[len(ot11),len(ot12),len(ot13),len(ot14),len(ot15),len(ot16),len(ot17),len(ot18),len(ot19),len(ot20),len(ot21)]
y=[ot2011,ot2012,ot2013,ot2014,ot2015,ot2016,ot2017,ot2018,ot2019,ot2020,ot2021]


sns.set_theme(style="whitegrid")
ax = sns.barplot(x=x, y=y, palette="Set2",color="xkcd:light grey")
# set the title of the graph

# Bold the title
ax.title.set_fontweight('bold')
ax.set_title('Overtime payroll from year 2012 to year 2021')
# set the x and y labels
ax.set(xlabel='Number emplotyees paid overtime at this year', ylabel='Total Overtime payment spent on this year ')
for p in ax.patches:
    if p.get_height() > 120000000:
        p.set_color('#EF404E')
    else:
        p.set_color('#0055AA')

# make more space between each x bar



plt.subplots_adjust(bottom=0.3, top=0.9)


# use Use GT America font for the title
ax.title.set_fontname('GT America')

# bold the title
ax.title.set_fontweight('bold')

# use GT America other words and numbers
ax.set_xlabel('Number emplotyees paid overtime at this year', fontname='GT America')
ax.set_ylabel('Total Overtime payment spent on this year', fontname='GT America')

# redude the font size of the x and y labels
ax.xaxis.label.set_size(10)
ax.yaxis.label.set_size(10)

# Remove the border line box around plots

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# show the graph
plt.show()
# Out:
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.

# %%
# QUESTION 14 REVAMP (Ryan)
import plotly.graph_objects as go
import plotly_express as px


# Overtime according to Employee Earnings Report  https://data.boston.gov/dataset/employee-earnings-report
ot2022=df22['OVERTIME'].sum()
ot2021=df21['OVERTIME'].sum()
ot2020=ot20.sum()
ot2019=ot19.sum()
ot2018=ot18.sum()
ot2017=ot17.sum()
ot2016=ot16.sum()
ot2015=ot15.sum()
ot2014=ot14.sum()
ot2013=ot13.sum()
ot2012=ot12.sum()
ot2011=ot11.sum()



# Overtime according to Full Budget Document https://www.boston.gov/departments/budget#current-and-past-fiscal-year-budgets (Bottom of page)
doc_ot2021 = 68218769
doc_ot2020 = 74694594
doc_ot2019 = 69759822
doc_ot2018 = 67908633
doc_ot2017 = 60315934
doc_ot2016 = 57479518
doc_ot2015 = 59880626
doc_ot2014 = 56684183
doc_ot2013 = 46124093
doc_ot2012 = 45559992
doc_ot2011 = 40347052

doc_ot = [doc_ot2011, doc_ot2012, doc_ot2013, doc_ot2014, doc_ot2015, doc_ot2016, doc_ot2017, doc_ot2018, doc_ot2019, doc_ot2020, doc_ot2021]

# Number of Personnel according to Full Budget Document
doc_pers2021 = 3126
doc_pers2020 = 3078
doc_pers2019 = 3014
doc_pers2018 = 3015
doc_pers2017 = 3014
doc_pers2016 = 3003
doc_pers2015 = 2958
doc_pers2014 = 2949
doc_pers2013 = 2948
doc_pers2012 = 2943
doc_pers2011 = 2909

doc_pers = [doc_pers2011, doc_pers2012, doc_pers2013, doc_pers2014, doc_pers2015, doc_pers2016, doc_pers2017, doc_pers2018, doc_pers2019, doc_pers2020, doc_pers2021]

# Employee Earnings Report Dataframe
# df_eer = pd.DataFrame(dict(
#     x=[len(ot11),len(ot12),len(ot13),len(ot14),len(ot15),len(ot16),len(ot17),len(ot18),len(ot19),len(ot20),len(ot21)],
#     y=[ot2011,ot2012,ot2013,ot2014,ot2015,ot2016,ot2017,ot2018,ot2019,ot2020,ot2021]
# ))

# Full Budget Document Dataframe
# df_fbd = pd.DataFrame(dict(
#     x=doc_pers,
#     y=doc_ot
# ))

# px.scatter(df, x="x", y="y", text=[" 2011","2011","2011","2011","2011","2011","2011","2011","2011","2011","2011"], title="Unsorted Input") 

fig = go.Figure()

# Color of each marker
colors = ['#130f54', '#4a1c52', '#5b2052', '#6a2352', '#7d2851', '#912c51', '#a53050', '#b9344f', '#cb384f', '#dd3c4e', '#ef404e']

fig.add_trace(go.Scatter(
    x=doc_pers,
    y=doc_ot,
    mode="lines+markers+text",
    name="Lines, Markers and Text",
    text=["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],
    textposition=["top center", "top left", "top center", "middle left",
                  "top center", "bottom center", "bottom right", "middle left", 
                  "top center", "top center", "top center"],
    line=dict(dash='dot', width=2, color='LightGray'),
    marker=dict(size=10, color=colors),
    textfont={
        "size": 14
    }
))

# Customize title to add captions!
fig.update_layout(
    title=go.layout.Title(
        text="More Departmental Personnel Associated with Higher Overtime Spending",
        xref="paper",
        x=0,
        font_family="GT America Bold",
        font_size=20
    )
)

# Aesthetic customizations
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    yaxis_title=None,
    yaxis_tickprefix = '$',
    margin=dict(
        l=100,
        r=100,
        b=80,
        t=90,
        pad=4
    ),
    height=550,
    width=1000
)

# Grid lines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='LightGray')


fig.update_layout(xaxis_title="Number of Department Personnel", yaxis_title="Annual Overtime Spending")
fig.write_html("html/Q14.html")
fig.show()
