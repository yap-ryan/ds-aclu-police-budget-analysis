# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager
from pathlib import Path
import matplotlib.ticker as mtick

#formats for currency 
import locale

# %%
LightOrange='#FCAA17'
DarkGreen='#FCAA17'
Red = '#EF404E'
DarkPurple = '#552564'
Blue='#0055AA'
DarkNavy='#130F54'
DarkSlate='#3C3532'
DarkBurgundy='#691B40'
OffBlack='#231F20'
LightSlate='#EFECEA'
LightYellow='#FFE06A'
LightGreen='#FFE06A'
LightPink='#FABEAF'
LightAzure='#A3DBE3'
Gray20='#CCCCCC'

# %%
earnings21 = pd.DataFrame(pd.read_csv('./Data/employees-2021.csv', encoding='latin1'))


earnings21['TOTAL_GROSS']=earnings21['TOTAL_GROSS'].apply(lambda x: float(x.replace(",","")))

fpath = Path("./fonts/ttf/GT-America-Standard-Regular.ttf")
fpath_bold = Path("./fonts/ttf/GT-America-Standard-Bold.ttf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [3], line 4
#       1 earnings21 = pd.DataFrame(pd.read_csv('./Data/employees-2021.csv', encoding='latin1'))
# ----> 4 earnings21['TOTAL_GROSS']=earnings21['TOTAL_GROSS'].apply(lambda x: float(x.replace(",","")))
#       6 fpath = Path(mpl.get_data_path(), "fonts/ttf/GT-America-Standard-Regular.ttf")
#       7 fpath_bold = Path(mpl.get_data_path(), "fonts/ttf/GT-America-Standard-Bold.ttf")
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/series.py:4774, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4664 def apply(
#    4665     self,
#    4666     func: AggFuncType,
#    (...)
#    4669     **kwargs,
#    4670 ) -> DataFrame | Series:
#    4671     """
#    4672     Invoke function on values of Series.
#    4673
#    (...)
#    4772     dtype: float64
#    4773     """
# -> 4774     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/apply.py:1100, in SeriesApply.apply(self)
#    1097     return self.apply_str()
#    1099 # self.f is Callable
# -> 1100 return self.apply_standard()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/apply.py:1151, in SeriesApply.apply_standard(self)
#    1149     else:
#    1150         values = obj.astype(object)._values
# -> 1151         mapped = lib.map_infer(
#    1152             values,
#    1153             f,
#    1154             convert=self.convert_dtype,
#    1155         )
#    1157 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1158     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1159     #  See also GH#25959 regarding EA support
#    1160     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2919, in pandas._libs.lib.map_infer()
#
# Cell In [3], line 4, in <lambda>(x)
#       1 earnings21 = pd.DataFrame(pd.read_csv('./Data/employees-2021.csv', encoding='latin1'))
# ----> 4 earnings21['TOTAL_GROSS']=earnings21['TOTAL_GROSS'].apply(lambda x: float(x.replace(",","")))
#       6 fpath = Path(mpl.get_data_path(), "fonts/ttf/GT-America-Standard-Regular.ttf")
#       7 fpath_bold = Path(mpl.get_data_path(), "fonts/ttf/GT-America-Standard-Bold.ttf")
#
# AttributeError: 'float' object has no attribute 'replace'

# %% [markdown]
# Employee compensation comparison to non-BPD employees <br/>
#
#
#
#
# Data Visualizations
# 	-Pie/Graph of Boston City payroll BPD vs non BPD <br/>
# 	-Graph of total payroll per department <br/>

# %% [markdown]
# 	-Pie/Graph of Boston City payroll BPD vs non BPD

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']
colors = ["#FCAA17", "#FCAA17", "#EF404E",'#552564','#0055AA',
    '#130F54','#3C3532','#691B40','#231F20','#EFECEA',
    '#FFE06A','#FFE06A','#FABEAF','#A3DBE3','#CCCCCC' ]
font = fpath


# make data
x = ['BPD', 'Remainder of City']
y = [bpd_earnings21['TOTAL_GROSS'].sum(),
     nonbpd_earnings21['TOTAL_GROSS'].sum()]
# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)


cont = ax.bar(x,y, color=['#FCAA17',"#EFECEA"])
ax.set(ylim=(0, 1600000000),yticks=range(0,1600000000,300000000))
plt.ticklabel_format(style='plain', axis='y', useLocale=True)
#plt.xlabel('Department', fontsize=16, font=font)
#plt.ylabel('Total Payroll', fontsize=16, font=font)
#plt.title('Boston Police Department Budget Makes up Nearly a Quarter of the Cities Budget',fontsize=18, font=font)
ax.set_title('Boston Police Department budget makes up nearly a quarter of the cities budget.', font=fpath_bold)
ax.title.set_size(20)


plt.grid(which='major', axis='y', color='lightgrey', zorder=10.0)
ax.set_axisbelow(True)

ax.set_yticklabels(['$0 ','$300 mil ','$600 mil ','$900 mil ','$1.2 bil ','$1.5 bil '])


locale.setlocale(locale.LC_ALL, '')
labels = []
for i in y:
    labels.append(locale.currency(i, grouping=True))
    
ax.bar_label(container=cont, labels=labels,fontsize=14,font=font)
plt.xticks(font=fpath)
plt.yticks(font=fpath)
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
   
fig.savefig('./final_images/8/Boston Police Department budget makes up nearly a quarter of the cities budget.png')



plt.show()

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']
colors = ["#FCAA17", "#FCAA17", "#EF404E",'#552564','#0055AA',
    '#130F54','#3C3532','#691B40','#231F20','#EFECEA',
    '#FFE06A','#FFE06A','#FABEAF','#A3DBE3','#CCCCCC' ]
font = fpath


# make data
x = ['BPD', 'Remainder of City']
y = [len(bpd_earnings21['TOTAL_GROSS'].index),
     len(nonbpd_earnings21['TOTAL_GROSS'].index)]
# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)


cont = ax.bar(x,y, color=['#FCAA17',"#EFECEA"])
_=ax.set(ylim=(0, 22000),yticks=range(0,22000,5000))
_=plt.ticklabel_format(style='plain', axis='y', useLocale=True)
#_=plt.xlabel('Department', fontsize=16, font=font)
plt.ylabel('Total Employees', fontsize=16, font=font)
#plt.title('City of Boston Payroll Breakdown',fontsize=18, font=font)
ax.set_title('Boston Police Department employees make up less than \n14% of the cities total employees.', font=fpath_bold)
ax.title.set_size(20)

#_= plt.grid(axis='y')
plt.grid(which='major', axis='y', color='lightgrey', zorder=10.0)
ax.set_axisbelow(True)


_= ax.bar_label(container=cont, labels=y,fontsize=14,font=font)
plt.xticks(font=fpath)
plt.yticks(font=fpath)


for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/Boston Police Department employees make up less than 14p of the cities total employees.png')

plt.show()

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']
colors = ["#FCAA17", "#FCAA17", "#EF404E",'#552564','#0055AA',
    '#130F54','#3C3532','#691B40','#231F20','#EFECEA',
    '#FFE06A','#FFE06A','#FABEAF','#A3DBE3','#CCCCCC' ]
font = fpath


# make data
x = ['Remainder of City','BPD']
y = [ nonbpd_earnings21['TOTAL_GROSS'].sum() 
     / len(nonbpd_earnings21['TOTAL_GROSS'].index),
     bpd_earnings21['TOTAL_GROSS'].sum() 
     / len(bpd_earnings21['TOTAL_GROSS'].index)]
# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)


cont = ax.bar(x,y, color=["#EFECEA",'#FCAA17'])
ax.set(ylim=(0, 160000),yticks=range(0,160000,30000))
plt.ticklabel_format(style='plain', axis='y', useLocale=True)

ax.set_title('On average, BPD employees salaries are nearly double that of all \nother city employees.',fontsize=18, font=fpath_bold)
ax.title.set_size(20)


locale.setlocale(locale.LC_ALL, '')
labels = []
for i in y:
    labels.append(locale.currency(i, grouping=True))


fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
ax.yaxis.set_major_formatter(tick)
ax.bar_label(container=cont, labels=labels,fontsize=14,font=font)
plt.xticks(font=fpath)
plt.yticks(font=fpath)
#ax.yaxis.set_major_formatter('${x:1.0f}')

plt.grid(which='major', axis='y', color='lightgrey', zorder=10.0)
ax.set_axisbelow(True)


for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/On average, BPD employees salaries are nearly double that of all other city employees.png')

plt.show()

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']

    
colors = ['#EFECEA','#FFE06A','#FABEAF','#A3DBE3','#CCCCCC']
font = fpath

# make the data
y = [earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']['TOTAL_GROSS'].sum(),
    earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']['TOTAL_GROSS'].sum()]
x = ['BPD ', 'Remainder of City ']


# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)

explode=(0,0.1)

#ax.set_title("Boston City Budget Breakdown for the 2021 Fiscal Year",font=font)
ax.set_title('Boston City Budget Breakdown for the 2021 Fiscal Year', font=fpath_bold)
ax.title.set_size(20)

_= ax.pie(y,labels=x, explode=explode, colors=['#FCAA17',"#EFECEA"],
       autopct='%.1f%%',textprops={'font':fpath}, shadow=False,
       wedgeprops=dict(width=1, edgecolor='w'))
ax.axis('equal')

#ax.legend(prop=font)


for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/Boston City Budget Breakdown for the 2021 Fiscal Year.png')

plt.show()

# %% [markdown]
# 	-Graph of total payroll per department

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']

    
colors = ['#EFECEA','#FFE06A','#FABEAF','#A3DBE3','#CCCCCC']
font = fpath

# make the data
x = []
y = []

ls = []
for i in earnings21['DEPARTMENT_NAME'].unique():
    ls.append(((earnings21[earnings21['DEPARTMENT_NAME']==i]['TOTAL_GROSS'].sum()),i))

ls.sort(reverse=True)
#print(ls)
for i,j in ls:
    y.append(i)
    x.append(j)



#y.sort(reverse=True)



# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)

colors = []
for y2 in y[0:20]:
    if y2 > np.array(y[0:20]).mean()+(np.array(y[0:20]).mean()/2):
        colors.append('#FCAA17')
    else:
        colors.append('#EFECEA')
cont = ax.barh(x[0:20],y[0:20], color=colors)
ax.set(xlim=(0, 550000000),xticks=range(0,550000000,100000000))
plt.ticklabel_format(style='plain', axis='x', useLocale=True)
plt.yticks(rotation = 0) # Rotates X-Axis Ticks by 45-degrees
#plt.ylabel('Department', fontsize=16, font=font)
plt.xlabel('Total Payroll', fontsize=16, font=font)
plt.suptitle('Boston Police Department\'s payroll is larger than the next 5 largest payrolls.',fontsize=18, font=fpath_bold)
ax.set_title('Boston Police Department\'s payroll is larger than the top 20 payrolls\n not including Boston Fire Department.',fontsize=18, font=font)
ax.title.set_size(14)
plt.grid(axis='x')

sum =0
check  =408762469.35
i=0
ls3 =y[0:20]
while sum < check:
    if ls3[i]!=check:
        sum += ls3[i]
    i+=1
print(i, "  ,",sum)


locale.setlocale(locale.LC_ALL, '')
labels = []
for i in y[0:20]:
    labels.append('   '+locale.currency(i, grouping=True))
    


ax.bar_label(container=cont, labels=labels,fontsize=14,font=font, rotation=0)
plt.xticks(font=fpath)
plt.yticks(font=fpath)

ax.set_xticklabels(['$0 ','$100 mil ','$020 mil ','$300 mil ','$400 mil ','$500 mil '])



for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/Boston Police Departments Payroll is Larger Than The Next 5 Largest Payrolls.png')

plt.show()
# Out:
# 6   , 414529728.5799999

# %%
# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)


# make the data
x = []
y = []

ls = []
for i in earnings21['DEPARTMENT_NAME'].unique():
    ls.append(((earnings21[earnings21['DEPARTMENT_NAME']==i]['TOTAL_GROSS'].sum()),i))

ls.sort(reverse=False)
#print(ls)
for i,j in ls:
    y.append(i)
    x.append(j)


colors = []
for y2 in y[0:20]:
    if y2 > np.array(y[0:20]).mean()+(np.array(y[0:20]).mean()/2):
        colors.append('#FCAA17')
    else:
        colors.append('#EFECEA')

cont = ax.barh(x[0:20],y[0:20], color=colors)
ax.set(xlim=(0, 550000), xticks=range(0,550000,100000))
plt.ticklabel_format(style='plain', axis='x', useLocale=True)
plt.yticks(rotation = 0) # Rotates X-Axis Ticks by 45-degrees
#plt.ylabel('Department', fontsize=16, font=font)
#plt.xlabel('Amount Spent on Payroll', fontsize=16, font=font)
#plt.title('City of Boston Payroll Breakdown, 20 Smallest Payrolls',fontsize=18, font=font)
ax.set_title('Breakdown of City of Boston\'s 20 Smallest Payrolls', font=fpath_bold)
ax.title.set_size(20)

plt.grid(which='major', axis='y', color='lightgrey', zorder=10.0)
plt.grid(which='major', axis='x', color='lightgrey', zorder=10.0)
ax.set_axisbelow(True)


locale.setlocale(locale.LC_ALL, '')
labels = []
for i in y[0:20]:
    labels.append('   '+locale.currency(i, grouping=True))
    
ax.bar_label(container=cont, labels=labels,fontsize=14,font=font, rotation=0)
plt.xticks(font=fpath)
plt.yticks(font=fpath)

ax.set_xticklabels(['$0 ','$100,000 ','$200,000 ','$300,000 ','$400,000 ','$500,000 '])


for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/Breakdown of City of Bostons 20 Smallest Payrolls.png')

plt.show()

# %%
bpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']=='Boston Police Department']
nonbpd_earnings21 = earnings21[earnings21['DEPARTMENT_NAME']!='Boston Police Department']

    
colors = ['#FCAA17','#EFECEA','#EFECEA','#EFECEA','#EFECEA','#EFECEA',
    '#EFECEA','#EFECEA','#EFECEA','#EFECEA']
# make the data
x = []
y = []

ls = []
for i in earnings21['DEPARTMENT_NAME'].unique():
    ls.append(((earnings21[earnings21['DEPARTMENT_NAME']==i]['TOTAL_GROSS'].sum()),i))

ls.sort(reverse=True)
#print(ls)
for i,j in ls:
    y.append(i)
    x.append(j)


# plot
fig, ax = plt.subplots()

fig.set_figheight(10)
fig.set_figwidth(10)

y_pie = y[:9]
sum = 0
for i in y[9:]:
    sum+=i
y_pie.append(sum)
x_labels = x[:9]
x_labels.append('All other departments')
_= ax.pie(y_pie,labels=x_labels, colors=colors,
       autopct='%.1f%%',textprops={'font':font}, 
       wedgeprops=dict(width=1, edgecolor='w'))
plt.title('City of Boston Payroll Breakdown, Top 10 Largest Payrolls',fontsize=18, font=font)
ax.set_title('Boston Police Department payroll makes up over 21% of the cities total payroll.', font=fpath_bold)
ax.title.set_size(20)



for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
fig.savefig('./final_images/8/Boston Police Department Payroll Makes Up Over 21p of The Cities Total Payroll.png')

plt.show()
