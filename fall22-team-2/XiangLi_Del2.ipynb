# %% [markdown]
# ## We will the data form 2021 to analysis.
# Data from https://data.boston.gov/dataset/employee-earnings-report.

# %%
import pandas as pd
df=pd.read_csv('./Data/employees-2021.csv',thousands=',', encoding='latin-1')
df.head()
type(df['OTHER'][0])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1083, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1233, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1246, in pandas._libs.parsers.TextReader._string_convert()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1444, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 13: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [1], line 2
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('./Data/employees-2021.csv',thousands=',')
#       3 df.head()
#       4 type(df['OTHER'][0])
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1772, in TextFileReader.read(self, nrows)
#    1765 nrows = validate_integer("nrows", nrows)
#    1766 try:
#    1767     # error: "ParserBase" has no attribute "read"
#    1768     (
#    1769         index,
#    1770         columns,
#    1771         col_dict,
# -> 1772     ) = self._engine.read(  # type: ignore[attr-defined]
#    1773         nrows
#    1774     )
#    1775 except Exception:
#    1776     self.close()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:243, in CParserWrapper.read(self, nrows)
#     241 try:
#     242     if self.low_memory:
# --> 243         chunks = self._reader.read_low_memory(nrows)
#     244         # destructive to chunks
#     245         data = _concatenate_chunks(chunks)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:890, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1037, in pandas._libs.parsers.TextReader._convert_column_data()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1090, in pandas._libs.parsers.TextReader._convert_tokens()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1233, in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1246, in pandas._libs.parsers.TextReader._string_convert()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1444, in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 13: invalid continuation byte

# %%
total_regular=df['REGULAR'].sum()
total_retro=df['RETRO'].sum()
total_other=df['OTHER'].sum()
total_gross=df['TOTAL_GROSS'].sum()
total_overtime=df['OVERTIME'].sum()
total_quinn=df['QUINN_EDUCATION_INCENTIVE'].sum()
total_injured=df['INJURED'].sum()
data=[total_regular,total_retro,total_other,total_other,total_quinn,total_injured]
title=['REGULAR','RETRO','OTHER','OVERTIME','QUINN EDUCATION INCENTIVE','INJURED']
import matplotlib.pyplot as plt
import plotly.express as px

fig = px.pie(df, values=data, names=title, title='<b>Pay roll distrubution of overtime</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(font=dict(family="GT America"))

fig.show()
print(data)
# Out:
# [1553539917.87, 6488771.77, 65149079.75999999, 65149079.75999999, 28538104.2, 49033942.99]

# %% [markdown]
# ## We can see that regular(base)  is  taking the majority of the of the payroll which is 87.9% while other takes 3.69% overtime takes 3.69%, retro takes 0.367%,  quinn education incentive takes about 1.61%, and injured takes 2.77%.

# %%
df
# Out:
#                         NAME           DEPARTMENT_NAME  \
# 0            Beckers,Richard  Boston Police Department
# 1      McGowan,Jacqueline M.  Boston Police Department
# 2             Harris,Shawn N  Boston Police Department
# 3          Washington,Walter  Boston Police Department
# 4          Mosley Jr.,Curtis  Boston Police Department
# ...                      ...                       ...
# 22547                    NaN                       NaN
# 22548                    NaN                       NaN
# 22549                    NaN                       NaN
# 22550                    NaN                       NaN
# 22551                    NaN                       NaN
#
#                                 TITLE    REGULAR  RETRO       OTHER  OVERTIME  \
# 0                      Police Officer        NaN    NaN  1264843.63       NaN
# 1                      Police Officer        NaN    NaN  1252990.81       NaN
# 2      Police Offc Comm Serv Offc 3$8   69772.10    NaN   212739.48  82300.87
# 3                      Police Officer  100963.38    NaN   211900.28  67849.66
# 4      Police Offc Comm Serv Offc 3$8  109858.02    NaN   192097.54  75938.65
# ...                               ...        ...    ...         ...       ...
# 22547                             NaN        NaN    NaN         NaN       NaN
# 22548                             NaN        NaN    NaN         NaN       NaN
# 22549                             NaN        NaN    NaN         NaN       NaN
# 22550                             NaN        NaN    NaN         NaN       NaN
# 22551                             NaN        NaN    NaN         NaN       NaN
#
#         INJURED   DETAIL  QUINN_EDUCATION_INCENTIVE  TOTAL_GROSS POSTAL
# 0           NaN      NaN                        NaN   1264843.63  02119
# 1           NaN      NaN                        NaN   1252990.81  02129
# 2      30939.24  12144.0                   25178.06    433073.75  02130
# 3           NaN   9016.0                   10096.55    399825.87  02368
# 4           NaN  19550.0                        NaN    397444.21  02301
# ...         ...      ...                        ...          ...    ...
# 22547       NaN      NaN                        NaN          NaN    NaN
# 22548       NaN      NaN                        NaN          NaN    NaN
# 22549       NaN      NaN                        NaN          NaN    NaN
# 22550       NaN      NaN                        NaN          NaN    NaN
# 22551       NaN      NaN                        NaN          NaN    NaN
#
# [22552 rows x 12 columns]

# %% [markdown]
# Now, we are going the visiualize the distrubution plot of each payroll

# %%
import seaborn as sns

sns.set_style('whitegrid')
sns.distplot(df['REGULAR'], kde = True, color ='#0055aa', bins = 30)
# bold the title
#remove the x and y labels
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of Regular Pay', fontweight ="bold", fontfamily = 'GT America Bold')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_40521/1656016214.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="REGULAR", nbins=30, title='<b>Distribution of Regular Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='Number of employmees')


fig.update_layout(font=dict(family="GT America"))

fig.show()

# %% [markdown]
# ## We can see the reglar(Base) payroll is most clustered in range 50000 to 120000

# %%
sns.distplot(df['OTHER'], kde = True, color ='#0055aa', bins = 30)
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of OTHER Pay', fontweight ="bold", fontfamily = 'GT America')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_40521/2182172721.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.

# %%
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="OTHER", nbins=30, title='<b>Distribution of OTHER Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='')


fig.update_layout(font=dict(family="GT America"))

# exchange the x aix and y axis
fig.update_xaxes(side="bottom")
fig.update_yaxes(side="left")


fig.show()

# %%
df['OTHER']
# Out:
# 0        1264843.63
# 1        1252990.81
# 2         212739.48
# 3         211900.28
# 4         192097.54
#             ...
# 22547           NaN
# 22548           NaN
# 22549           NaN
# 22550           NaN
# 22551           NaN
# Name: OTHER, Length: 22552, dtype: float64

# %%
sns.distplot(df['RETRO'], kde = True, color ='#0055aa', bins = 30)
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of RETRO Pay', fontweight ="bold", fontfamily = 'GT America')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_40521/1036161441.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.

# %%
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="RETRO", nbins=30, title='<b>Distribution of RETRO Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='Number of Employees')


fig.update_layout(font=dict(family="GT America"))

fig.show()

# %%
sns.distplot(df['OVERTIME'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_4174/3227685570.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='OVERTIME', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="OVERTIME", nbins=30, title='<b>Distribution of OVERTIME Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='Number of employmees')


fig.update_layout(font=dict(family="GT America"))

fig.show()

# %% [markdown]
# ## The overtime payroll is mainly clustered at range 0 to 25000

# %%
sns.distplot(df['QUINN_EDUCATION_INCENTIVE'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_4174/3519285862.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='QUINN_EDUCATION_INCENTIVE', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="QUINN_EDUCATION_INCENTIVE", nbins=30, title='<b>Distribution of QUINN_EDUCATION_INCENTIVE Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='Number of employmees')


fig.update_layout(font=dict(family="GT America"))

fig.show()

# %% [markdown]
# ## The quinn education incentive is mainly clustered in range 10000 t0 30000

# %%
sns.distplot(df['INJURED'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/_h/n4z6x9sx4s18b6l_lb44jpzc0000gn/T/ipykernel_4174/2909604333.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot:xlabel='INJURED', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="INJURED", nbins=30, title='<b>Distribution of INJURED Pay</b>')
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='Number of employmees')


fig.update_layout(font=dict(family="GT America"))

fig.show()

# %% [markdown]
# ## The payroll of injured is mainly injured in rang 0 to 25000
