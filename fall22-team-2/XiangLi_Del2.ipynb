# %% [markdown]
# ## We will the data form 2021 to analysis.
# Data from https://data.boston.gov/dataset/employee-earnings-report.

# %%
import pandas as pd
df=pd.read_csv('./Data/employees-2021.csv',thousands=',', encoding='latin-1')
df.head(20)
# type(df['OTHER'][0])
# Out:
#                        NAME           DEPARTMENT_NAME  \
# 0           Beckers,Richard  Boston Police Department
# 1     McGowan,Jacqueline M.  Boston Police Department
# 2            Harris,Shawn N  Boston Police Department
# 3         Washington,Walter  Boston Police Department
# 4         Mosley Jr.,Curtis  Boston Police Department
# 5           Joseph,Martin M  Boston Police Department
# 6          Demesmin,Stanley  Boston Police Department
# 7              Smith,Sean P  Boston Police Department
# 8                Lee,Waiman  Boston Police Department
# 9         Barrett,Thomas E.  Boston Police Department
# 10         Danilecki,John H  Boston Police Department
# 11             Webb,Keith A  Boston Police Department
# 12        Hocking,Michael E    Boston Fire Department
# 13           Sweeney,Steven  Boston Police Department
# 14             Brown,John M  Boston Police Department
# 15       Doherty,Michael J.    Boston Fire Department
# 16        Kervin,Timothy M.  Boston Police Department
# 17         Downing,George C  Boston Police Department
# 18         Connolly,Timothy  Boston Police Department
# 19  Harrington,Mark William  Boston Police Department
#
#                              TITLE    REGULAR  RETRO       OTHER   OVERTIME  \
# 0                   Police Officer        NaN    NaN  1264843.63        NaN
# 1                   Police Officer        NaN    NaN  1252990.81        NaN
# 2   Police Offc Comm Serv Offc 3$8   69772.10    NaN   212739.48   82300.87
# 3                   Police Officer  100963.38    NaN   211900.28   67849.66
# 4   Police Offc Comm Serv Offc 3$8  109858.02    NaN   192097.54   75938.65
# 5            Police Sergeant (Det)  127626.76    NaN   124524.50   66433.83
# 6          Police Lieutenant (Det)  142466.41    NaN    15820.50  167509.61
# 7                Police Lieutenant  143566.78    NaN    16789.43  109101.43
# 8                 Police Detective  107352.54    NaN    16324.27   76434.46
# 9            Police Sergeant (Det)  130930.12    NaN    16723.95  166042.24
# 10                  Police Captain  157595.81    NaN    24504.13   49388.68
# 11           Police Sergeant (Det)  130930.12    NaN    19722.83  109031.27
# 12                  Dep Fire Chief  187602.91    NaN     9935.46   75459.19
# 13              Police Captain/DDC  159603.67    NaN    24423.09  104610.39
# 14           Police Sergeant (Det)  130930.12    NaN    19672.83  150490.63
# 15                  Dep Fire Chief  201164.38    NaN     9910.46   52774.34
# 16   Lieut-Hackney Carriage Inves.  139239.28    NaN    20912.37   41962.42
# 17  Police Offc Comm Serv Offc 3$8   99906.76    NaN   208143.50    9654.57
# 18              Police Captain/DDC  157980.06    NaN    22338.83  101772.10
# 19              Police Captain/DDC  164500.82    NaN    24511.81   88265.54
#
#      INJURED    DETAIL  QUINN_EDUCATION_INCENTIVE  TOTAL_GROSS POSTAL
# 0        NaN       NaN                        NaN   1264843.63  02119
# 1        NaN       NaN                        NaN   1252990.81  02129
# 2   30939.24   12144.0                   25178.06    433073.75  02130
# 3        NaN    9016.0                   10096.55    399825.87  02368
# 4        NaN   19550.0                        NaN    397444.21  02301
# 5        NaN   50085.0                   12762.78    381432.87  02124
# 6        NaN   24695.0                   28198.49    378690.01  02052
# 7        NaN   53240.0                   35891.85    358589.49  02186
# 8        NaN  123234.0                   26838.11    350183.38  02134
# 9        NaN       NaN                   32732.73    346429.04  02132
# 10   6504.89   64800.0                   41025.08    343818.59  02559
# 11       NaN   46587.0                   32732.73    339003.95  02121
# 12  33276.47   30562.0                        NaN    336836.03  02332
# 13   4281.69    2520.0                   40971.27    336410.11  02131
# 14       NaN    1802.0                   32732.73    335628.31  02136
# 15  19715.00   49018.5                        NaN    332582.68  01867
# 16       NaN   94325.0                   34809.82    331248.89  02135
# 17       NaN    2208.0                    9990.83    329903.66  02021
# 18   6520.76       NaN                   41125.37    329737.12  02186
# 19       NaN    7080.0                   41125.37    325483.54  02184

# %%
import plotly.graph_objects as go

df = df.loc[df['DEPARTMENT_NAME'] == 'Boston Police Department']

total_regular=df['REGULAR'].sum()
total_retro=df['RETRO'].sum()
total_other=df['OTHER'].sum()
total_detail=df['DETAIL'].sum()
total_gross=df['TOTAL_GROSS'].sum()
total_overtime=df['OVERTIME'].sum()
total_quinn=df['QUINN_EDUCATION_INCENTIVE'].sum()
total_injured=df['INJURED'].sum()
data=[total_regular,total_retro,total_other,total_overtime,total_quinn,total_injured, total_detail]
names=['Regular','Retro','Other','Overtime','Quinn Education Incentive','Injured','Detail']


import matplotlib.pyplot as plt
import plotly.express as px

fig = px.pie(df, values=data, names=names, color_discrete_sequence=["#130F54",'#EF404E','#BBBBBB', '#FCAA17', '#691B40', '#0055AA', '#EFECEA'],)
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular

fig.update_layout(
    font_family="GT America",   
    font_size=12, 
    width=630,
    height=640)

fig.update_layout(
    title = go.layout.Title(
        text = "Type Distribution of BPD Payroll in FY 2021<br>",
        xref = "paper",
        x = 0,
        font_family = "GT America Bold",
        font_size = 20,
        font_color="black"
    ),
    margin=dict(
        t=100
    )
)

fig.update_traces(showlegend=False, textposition='inside', textinfo='percent+label')

fig.show()
print(data)
# Out:
# [235162278.84000003, 0.0, 20718763.82, 72223009.96000001, 28423036.139999997, 26063147.89, 24586101.0]

# %% [markdown]
# ## We can see that regular(base)  is  taking the majority of the of the payroll which is 87.9% while other takes 3.69% overtime takes 3.69%, retro takes 0.367%,  quinn education incentive takes about 1.61%, and injured takes 2.77%.

# %%
df
# Out:
#                         NAME           DEPARTMENT_NAME  \
# 0            Beckers,Richard  Boston Police Department
# 1      McGowan,Jacqueline M.  Boston Police Department
# 2             Harris,Shawn N  Boston Police Department
# 3          Washington,Walter  Boston Police Department
# 4          Mosley Jr.,Curtis  Boston Police Department
# ...                      ...                       ...
# 22363           Mejia,Alfred  Boston Police Department
# 22364             Pires,Luis  Boston Police Department
# 22365     Rogers,Michelle M.  Boston Police Department
# 22403  Austin,Eleanor Louise  Boston Police Department
# 22453   Marks,Shalysha Monai  Boston Police Department
#
#                                 TITLE    REGULAR  RETRO       OTHER  OVERTIME  \
# 0                      Police Officer        NaN    NaN  1264843.63       NaN
# 1                      Police Officer        NaN    NaN  1252990.81       NaN
# 2      Police Offc Comm Serv Offc 3$8   69772.10    NaN   212739.48  82300.87
# 3                      Police Officer  100963.38    NaN   211900.28  67849.66
# 4      Police Offc Comm Serv Offc 3$8  109858.02    NaN   192097.54  75938.65
# ...                               ...        ...    ...         ...       ...
# 22363                  Police Officer     790.07    NaN         NaN       NaN
# 22364                  Police Officer     790.07    NaN         NaN       NaN
# 22365                  Police Officer     790.07    NaN         NaN       NaN
# 22403             School Traffic Supv     118.70    NaN      520.00       NaN
# 22453                  Cadet (Police)        NaN    NaN      400.00       NaN
#
#         INJURED   DETAIL  QUINN_EDUCATION_INCENTIVE  TOTAL_GROSS POSTAL
# 0           NaN      NaN                        NaN   1264843.63  02119
# 1           NaN      NaN                        NaN   1252990.81  02129
# 2      30939.24  12144.0                   25178.06    433073.75  02130
# 3           NaN   9016.0                   10096.55    399825.87  02368
# 4           NaN  19550.0                        NaN    397444.21  02301
# ...         ...      ...                        ...          ...    ...
# 22363       NaN      NaN                        NaN       790.07  02136
# 22364       NaN      NaN                        NaN       790.07  02125
# 22365       NaN      NaN                        NaN       790.07  02125
# 22403       NaN      NaN                        NaN       638.70  02136
# 22453       NaN      NaN                        NaN       400.00  02124
#
# [3094 rows x 12 columns]

# %% [markdown]
# Now, we are going the visiualize the distrubution plot of each payroll

# %%
import seaborn as sns

sns.set_style('whitegrid')
sns.distplot(df['REGULAR'], kde = True, color ='#0055aa', bins = 30)
# bold the title
#remove the x and y labels
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of Regular Pay', fontweight ="bold", fontfamily = 'GT America Bold')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/1656016214.py:4: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.
# findfont: Font family 'GT America Bold' not found.

# %%
# use plotly to do the thing in above cell
import plotly.express as px
from plotly.graph_objs import *

# Remove negative outliers
df = df.drop(df.index[df['REGULAR'] <= 0])

layout = Layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)'
)

# fig.update_traces(marker_color=['#0055aa'])

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="REGULAR", nbins=50, title='<b>Distribution of Regular Pay</b>', color_discrete_sequence=['#130F54'])

# remove the x and y labels
fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')


# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Regular Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()

# %% [markdown]
# ## We can see the reglar(Base) payroll is most clustered in range 50000 to 120000

# %%
sns.distplot(df['OTHER'], kde = True, color ='#0055aa', bins = 30)
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of Other Pay', fontweight ="bold", fontfamily = 'GT America')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/3375911676.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.

# %%
import plotly.express as px
# change the color of bars to #0055aa

# fig.update_traces(marker_color='#0055aa')


# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="OTHER", nbins=50, title='<b>Distribution of Other Pay</b>', color_discrete_sequence=['#130F54'])
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

# remove the x and y labels
fig.update_xaxes(title_text='')
fig.update_yaxes(title_text='')


fig.update_layout(font=dict(family="GT America"))

# exchange the x aix and y axis
fig.update_xaxes(side="bottom")
fig.update_yaxes(side="left")

fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Other Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)


fig.show()

# %%
df['OTHER']
# Out:
# 0        1264843.63
# 1        1252990.81
# 2         212739.48
# 3         211900.28
# 4         192097.54
#             ...
# 22363           NaN
# 22364           NaN
# 22365           NaN
# 22403        520.00
# 22453        400.00
# Name: OTHER, Length: 3083, dtype: float64

# %%
sns.distplot(df['RETRO'], kde = True, color ='#0055aa', bins = 30)
plt.xlabel('')
plt.ylabel('')
# change the title to GT America format
plt.title('Distribution of Retro Pay', fontweight ="bold", fontfamily = 'GT America')
#  Remove the border line box around plots
sns.despine(left = True, bottom = True)
plt.show()
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/4129861177.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /opt/homebrew/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning:
#
# invalid value encountered in divide
#
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.
# findfont: Font family 'GT America' not found.

# %%
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="RETRO", nbins=50, title='<b>Distribution of Retro Pay</b>', color_discrete_sequence=['#130F54'])
# change the frount of thing other than title to GT-America-Standard-regular
# add the kde line

fig.update_yaxes(title_text='Number of employmees')
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Other Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()

# %%
sns.distplot(df['OVERTIME'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/3227685570.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: xlabel='OVERTIME', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

# Remove negative values
df = df.drop(df.index[df['OVERTIME'] < 0])

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="OVERTIME", nbins=50, title='<b>Distribution of Overtime Pay</b>', color_discrete_sequence=['#130F54'])
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Overtime Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()

# %% [markdown]
# ## The overtime payroll is mainly clustered at range 0 to 25000

# %%
sns.distplot(df['QUINN_EDUCATION_INCENTIVE'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/3519285862.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: xlabel='QUINN_EDUCATION_INCENTIVE', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="QUINN_EDUCATION_INCENTIVE", nbins=50, title='<b>Distribution of Quinn Education Incentive Pay</b>', color_discrete_sequence=['#130F54'])
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Quinn Education Incentive Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()

# %% [markdown]
# ## The quinn education incentive is mainly clustered in range 10000 t0 30000

# %%
sns.distplot(df['INJURED'], kde = True, color ='red', bins = 30)
# Out:
# /var/folders/15/ngd639_x4tn_n4xh55wvc5lr0000gn/T/ipykernel_13353/2909604333.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: xlabel='INJURED', ylabel='Density'>

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

#Remove negative values
df = df.drop(df.index[df['INJURED'] < 0])

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="INJURED", nbins=50, title='<b>Distribution of Injured Pay</b>', color_discrete_sequence=['#130F54'])
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Injured Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()

# %% [markdown]
# ## The payroll of injured is mainly injured in rang 0 to 25000

# %%
# use plotly to do the thing in above cell
import plotly.express as px
# change the color of bars to #0055aa

fig.update_traces(marker_color='#0055aa')

#Remove negative values
df = df.drop(df.index[df['DETAIL'] < 0])

# make the background transparent in white
fig.update_layout(plot_bgcolor='rgba(0,0,0,0)')
fig = px.histogram(df, x="DETAIL", nbins=50, title='<b>Distribution of Detail Pay</b>', color_discrete_sequence=['#130F54'])
fig.update_layout(font_family="GT America Bold")
# change the frount of thing other than title to GT-America-Standard-regular
fig.update_xaxes(showgrid=False, gridwidth=0.5, gridcolor='LightGray')
# add the kde line

fig.update_yaxes(title_text='Number of employmees')
fig.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='LightGray')

# Font & other aesthetic stuff
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    font_family="GT America",
    font_color="black",
    xaxis_title=None,
    xaxis_tickprefix = '$',
    height=500,
    width=1100,
    margin=dict(
        l=100,
        r=100,
        b=100,
        t=100,
        pad=4
    )
    
)

# Customize title
fig.update_layout(
    title=go.layout.Title(
        text="Distribution of Detail Pay in 2021",
        xref="paper",
        x=0,
        y=0.9,
        font_family="GT America Bold",
        font_size=19
    )
)

fig.show()
